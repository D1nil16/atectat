# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('penguins.csv')
data.head()
# Out:
#    вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0    0       2         39.1          18.7           181.0      3750.0    1
# 1    0       2         39.5          17.4           186.0      3800.0    0
# 2    0       2         40.3          18.0           195.0      3250.0    0
# 3    0       2         36.7          19.3           193.0      3450.0    0
# 4    0       2         39.3          20.6           190.0      3650.0    1

# %%
#create scatterplot
plt.scatter (data['длина клюва'], data['масса тела'])

# %%
print(data.head())
# Out:
#    вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0    0       2         39.1          18.7           181.0      3750.0    1
# 1    0       2         39.5          17.4           186.0      3800.0    0
# 2    0       2         40.3          18.0           195.0      3250.0    0
# 3    0       2         36.7          19.3           193.0      3450.0    0
# 4    0       2         39.3          20.6           190.0      3650.0    1

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   вид             333 non-null    int64
#  1   остров          333 non-null    int64
#  2   длина клюва     333 non-null    float64
#  3   ширина клюва    333 non-null    float64
#  4   длина плавника  333 non-null    float64
#  5   масса тела      333 non-null    float64
#  6   пол             333 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 18.3 KB
# None

# %%
print(data.describe())
# Out:
#               вид      остров  длина клюва  ширина клюва  длина плавника  \
# count  333.000000  333.000000   333.000000    333.000000      333.000000
# mean     0.918919    0.651652    43.992793     17.164865      200.966967
# std      0.889718    0.714715     5.468668      1.969235       14.015765
# min      0.000000    0.000000    32.100000     13.100000      172.000000
# 25%      0.000000    0.000000    39.500000     15.600000      190.000000
# 50%      1.000000    1.000000    44.500000     17.300000      197.000000
# 75%      2.000000    1.000000    48.600000     18.700000      213.000000
# max      2.000000    2.000000    59.600000     21.500000      231.000000
#
#         масса тела         пол
# count   333.000000  333.000000
# mean   4207.057057    0.504505
# std     805.215802    0.500732
# min    2700.000000    0.000000
# 25%    3550.000000    0.000000
# 50%    4050.000000    1.000000
# 75%    4775.000000    1.000000
# max    6300.000000    1.000000

# %%
table = pd.DataFrame(data)  
print(table)
# Out:
#      вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0      0       2         39.1          18.7           181.0      3750.0    1
# 1      0       2         39.5          17.4           186.0      3800.0    0
# 2      0       2         40.3          18.0           195.0      3250.0    0
# 3      0       2         36.7          19.3           193.0      3450.0    0
# 4      0       2         39.3          20.6           190.0      3650.0    1
# ..   ...     ...          ...           ...             ...         ...  ...
# 328    2       0         47.2          13.7           214.0      4925.0    0
# 329    2       0         46.8          14.3           215.0      4850.0    0
# 330    2       0         50.4          15.7           222.0      5750.0    1
# 331    2       0         45.2          14.8           212.0      5200.0    0
# 332    2       0         49.9          16.1           213.0      5400.0    1
#
# [333 rows x 7 columns]

# %%
print(data)
# Out:
#      вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0      0       2         39.1          18.7           181.0      3750.0    1
# 1      0       2         39.5          17.4           186.0      3800.0    0
# 2      0       2         40.3          18.0           195.0      3250.0    0
# 3      0       2         36.7          19.3           193.0      3450.0    0
# 4      0       2         39.3          20.6           190.0      3650.0    1
# ..   ...     ...          ...           ...             ...         ...  ...
# 328    2       0         47.2          13.7           214.0      4925.0    0
# 329    2       0         46.8          14.3           215.0      4850.0    0
# 330    2       0         50.4          15.7           222.0      5750.0    1
# 331    2       0         45.2          14.8           212.0      5200.0    0
# 332    2       0         49.9          16.1           213.0      5400.0    1
#
# [333 rows x 7 columns]

# %%
comparison = data['масса тела'] == data['пол']
print(comparison)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Length: 333, dtype: bool

# %%
print(sorted_data)
# Out:
#      вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 136    0       1         32.1          15.5           188.0      3050.0    0
# 92     0       1         33.1          16.1           178.0      2900.0    0
# 64     0       2         33.5          19.0           190.0      3600.0    0
# 86     0       1         34.0          17.1           185.0      3400.0    0
# 13     0       2         34.4          18.4           184.0      3325.0    0
# ..   ...     ...          ...           ...             ...         ...  ...
# 326    2       0         55.1          16.0           230.0      5850.0    1
# 209    1       1         55.8          19.8           207.0      4000.0    1
# 313    2       0         55.9          17.0           228.0      5600.0    1
# 163    1       1         58.0          17.8           181.0      3700.0    0
# 246    2       0         59.6          17.0           230.0      6050.0    1
#
# [333 rows x 7 columns]

# %%
plt.plot(comparison)
plt.xlabels = comparison['масса']
plt.ylabels = comparison['пол']
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[170], line 2
#       1 plt.plot(comparison)
# ----> 2 plt.xlabels = comparison['масса']
#       3 plt.ylabels = comparison['пол']
#       4 plt.legend()
#
# File d:\code\KerasTest\.venv\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File d:\code\KerasTest\.venv\lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
table = pd.DataFrame(data)  
print(table)
# Out:
#      вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0      0       2         39.1          18.7           181.0      3750.0    1
# 1      0       2         39.5          17.4           186.0      3800.0    0
# 2      0       2         40.3          18.0           195.0      3250.0    0
# 3      0       2         36.7          19.3           193.0      3450.0    0
# 4      0       2         39.3          20.6           190.0      3650.0    1
# ..   ...     ...          ...           ...             ...         ...  ...
# 328    2       0         47.2          13.7           214.0      4925.0    0
# 329    2       0         46.8          14.3           215.0      4850.0    0
# 330    2       0         50.4          15.7           222.0      5750.0    1
# 331    2       0         45.2          14.8           212.0      5200.0    0
# 332    2       0         49.9          16.1           213.0      5400.0    1
#
# [333 rows x 7 columns]

# %%
plt.sort(data )

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 plt.bar(data, [1, 1, 1])
#       3 # Задаем высоту столбцов на основе значений
#       4 for i, v in enumerate(data):
#
# File d:\code\KerasTest\.venv\lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# File d:\code\KerasTest\.venv\lib\site-packages\matplotlib\__init__.py:1475, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1472 @functools.wraps(func)
# ...
